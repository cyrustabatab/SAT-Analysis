# %%
import pandas as pd

# %%
tracts = pd.read_csv("schools/median_income_by_census_tract.csv")

# %%
tracts[tracts.State == 'New York']
# Out:
#        FID  STATEFP10  COUNTYFP10  TRACTCE10      GEOID10  INTPTLAT10  \
# 1542  1542         36          85       1700  36085001700   40.634391
# 1543  1543         36          85        600  36085000600   40.618153
# 1544  1544         36          85        700  36085000700   40.647370
# 1545  1545         36          85       1800  36085001800   40.601909
# 1546  1546         36          85        300  36085000300   40.644630
# ...    ...        ...         ...        ...          ...         ...
# 4840  4840         36           5      18500  36005018500   40.826706
# 4841  4841         36           5      20900  36005020900   40.843068
# 4842  4842         36           5      22200  36005022200   40.835684
# 4843  4843         36           5      23800  36005023800   40.843709
# 4844  4844         36           5      37504  36005037504   40.850294
#
#       INTPTLON10     State           COUNTY  HH_COUNT  ...  MSMOC_TOT_  \
# ...
